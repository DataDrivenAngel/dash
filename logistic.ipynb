# %%
from scipy.stats import genlogistic
import matplotlib.pyplot as plt
import numpy as np
import time
fig, ax = plt.subplots(1, 1)

# %%
c = 0.412
mean, var, skew, kurt = genlogistic.stats(c, moments='mvsk')

# %%
x = np.linspace(genlogistic.ppf(0.01, c),
                genlogistic.ppf(0.99, c), 100)
ax.plot(x, genlogistic.pdf(x, c),
       'r-', lw=5, alpha=0.6, label='genlogistic pdf')

# %%
fig

# %%
x
# Out:
# array([-11.17758355, -11.02729286, -10.87700216, -10.72671146,
#        -10.57642076, -10.42613007, -10.27583937, -10.12554867,
#         -9.97525798,  -9.82496728,  -9.67467658,  -9.52438588,
#         -9.37409519,  -9.22380449,  -9.07351379,  -8.92322309,
#         -8.7729324 ,  -8.6226417 ,  -8.472351  ,  -8.3220603 ,
#         -8.17176961,  -8.02147891,  -7.87118821,  -7.72089751,
#         -7.57060682,  -7.42031612,  -7.27002542,  -7.11973472,
#         -6.96944403,  -6.81915333,  -6.66886263,  -6.51857193,
#         -6.36828124,  -6.21799054,  -6.06769984,  -5.91740914,
#         -5.76711845,  -5.61682775,  -5.46653705,  -5.31624635,
#         -5.16595566,  -5.01566496,  -4.86537426,  -4.71508356,
#         -4.56479287,  -4.41450217,  -4.26421147,  -4.11392077,
#         -3.96363008,  -3.81333938,  -3.66304868,  -3.51275798,
#         -3.36246729,  -3.21217659,  -3.06188589,  -2.91159519,
#         -2.7613045 ,  -2.6110138 ,  -2.4607231 ,  -2.3104324 ,
#         -2.16014171,  -2.00985101,  -1.85956031,  -1.70926962,
#         -1.55897892,  -1.40868822,  -1.25839752,  -1.10810683,
#         -0.95781613,  -0.80752543,  -0.65723473,  -0.50694404,
#         -0.35665334,  -0.20636264,  -0.05607194,   0.09421875,
#          0.24450945,   0.39480015,   0.54509085,   0.69538154,
#          0.84567224,   0.99596294,   1.14625364,   1.29654433,
#          1.44683503,   1.59712573,   1.74741643,   1.89770712,
#          2.04799782,   2.19828852,   2.34857922,   2.49886991,
#          2.64916061,   2.79945131,   2.94974201,   3.1000327 ,
#          3.2503234 ,   3.4006141 ,   3.5509048 ,   3.70119549])
